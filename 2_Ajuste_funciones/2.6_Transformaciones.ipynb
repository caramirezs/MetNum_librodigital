# %% [markdown]
# # 2.6 Transformaciones
#
# ## Funciones en python

# %%
import numpy as np #Librería numérica
import matplotlib.pyplot as plt # Para crear gráficos con matplotlib
import matplotlib.pyplot as plt #Librería gráfica

def grafica(x, y):
    plt.plot(x, y,'o')
    plt.show()

# Regresión lineal
def linear_regression(x, y):  
    print("********** Regresión lineal ***********") 
    sum_xi = np.sum(x)
    sum_xi_2 = np.sum(x**2)
    sum_yi = np.sum(y)
    sum_xiyi = np.sum(x*y)
    print(f'sum_xi: {sum_xi:.3f}, sum_xi_2: {sum_xi_2:.3f}')
    print(f'sum_yi: {sum_yi:.3f}, sum_xiyi: {sum_xiyi:.3f}')
    
    a = np.array([[sum_xi_2, sum_xi],
                [sum_xi, len(x)]])
    b = np.array([sum_xiyi ,sum_yi])
    solve = np.linalg.solve(a, b)    
    print(f'Solución del sistema: {solve}')
    print(f'Regresión lineal: y = {solve[0]:.3f}x + {solve[1]:.3f}')
    f_lin = lambda x: solve[0]*x + solve[1]    
    
    #grafica
    xi = np.linspace(np.min(x),np.max(x),1001)
    plt.plot(x, y,'o')
    plt.plot(xi, f_lin(xi),'-')
    plt.show()
    
def exponential_regression(x, y):  
    print("********** Regresión exponencial   ***********")     
    Y = np.log(y)
    print("Y ", Y)
    sum_xi = np.sum(x)
    sum_xi_2 = np.sum(x**2)
    sum_Yi = np.sum(Y)
    sum_xiYi = np.sum(x*Y)
    print(f'sum_xi: {sum_xi:.3f}, sum_xi_2: {sum_xi_2:.3f}')
    print(f'sum_yi: {sum_Yi:.3f}, sum_xiyi: {sum_xiYi:.3f}')
    a = np.array([[sum_xi_2, sum_xi],
                [sum_xi, len(x)]])
    b = np.array([sum_xiYi ,sum_Yi])
    solve_3 = np.linalg.solve(a, b)
    f_exp = lambda x: np.exp(solve_3[1]) * np.exp(solve_3[0]*x)
    a_0, a_1  = np.exp(solve_3[1]), solve_3[0]
    print(f'Regresión exponencial: Y = {a_0:.3f}*e^({a_1:.3f}*x)')

    print("************")
    xi = np.linspace(np.min(x),np.max(x),1001)
    print("Grafica con la regresión lineal ")
    plt.plot(x, Y,'ro')
    plt.show() 
    
    
    f_exp = lambda x: np.exp(solve_3[1]) * np.exp(solve_3[0]*x)
    a_0, a_1  = np.exp(solve_3[1]), solve_3[0]
    print(f'Regresión exponencial: Y = {a_0:.3f}*e^({a_1:.3f}*x)')
    
    xi = np.linspace(np.min(x),np.max(x),1001)
    plt.plot(x, y,'o')
    plt.plot(xi, f_exp(xi),'g-')
    plt.show()

    
def regli_trans_semi_log(x, y):  
    print("********** Regresión lineal (transformada semi-log) ***********")  
    Y = np.log(y)
    print("Y ", Y)
    sum_xi = np.sum(x)
    sum_xi_2 = np.sum(x**2)
    sum_Yi = np.sum(Y)
    sum_xiYi = np.sum(x*Y)
    print(f'sum_xi: {sum_xi:.3f}, sum_xi_2: {sum_xi_2:.3f}')
    print(f'sum_yi: {sum_Yi:.3f}, sum_xiyi: {sum_xiYi:.3f}')
    a = np.array([[sum_xi_2, sum_xi],
                [sum_xi, len(x)]])
    b = np.array([sum_xiYi ,sum_Yi])
    solve_3 = np.linalg.solve(a, b)
    print(f'Solución del sistema: {solve_3}')
    print(f'Regresión lineal (transformada semi-log): Y = {solve_3[0]:.3f}x + {solve_3[1]:.3f}')
    f_trans_lin = lambda x: solve_3[0]*x + solve_3[1]   
    
    xi = np.linspace(np.min(x),np.max(x),1001)
    plt.plot(x, Y,'ro')
    plt.plot(xi, f_trans_lin(xi),'-')
    plt.show()    

def quadratic_regression(x, y):  
    print("********** Regresión cuadrática ***********")   
    sum_xi = np.sum(x)
    sum_xi_2 = np.sum(x**2)
    sum_xi_3 = np.sum(x**3)
    sum_xi_4 = np.sum(x**4)
    sum_yi = np.sum(y)
    sum_xiyi = np.sum(x*y)
    sum_xi_2yi = np.sum(x**2*y)
    print(sum_xi, sum_xi_2, sum_xi_3, sum_xi_4)
    print(sum_yi, sum_xiyi, sum_xi_2yi)
    a = np.array([[sum_xi_4, sum_xi_3, sum_xi_2],
                [sum_xi_3, sum_xi_2, sum_xi],
                [sum_xi_2, sum_xi, len(x)]])
    b = np.array([sum_xi_2yi, sum_xiyi ,sum_yi])
    solve_2 = np.linalg.solve(a, b)
    f_cuad = lambda x: solve_2[0]*x**2 + solve_2[1]*x + solve_2[2]
    print(f'Regresión cuadrática: y = {solve_2[0]:.3f}x^2 + {solve_2[1]:.3f}x + {solve_2[2]:.3f}')  
    
    xi = np.linspace(np.min(x),np.max(x),1001)
    plt.plot(x, y,'o')
    plt.plot(xi, f_cuad(xi),'y-')
    plt.show()
    
def patenc_regression(x, y):  
    print("********** Regresión de potancia ***********")    
    
    Y = np.log(y)
    X = np.log(x)
    print("log y",Y )
    print("log x",X) 
    
    print("grafica con la tranfomación de patencia")
    Xi = np.linspace(np.min(X),np.max(X),1001)
    plt.plot(X, Y,'go')
    plt.show() 
    
    print("Regresión lineal (transformada semi-log)") 
    sum_Xi = np.sum(X)
    sum_Xi_2 = np.sum(X**2)
    sum_Yi = np.sum(Y)
    sum_XiYi = np.sum(X*Y)
    print(f'sum_xi: {sum_Xi:.3f}, sum_xi_2: {sum_Xi_2:.3f}')
    print(f'sum_yi: {sum_Yi:.3f}, sum_xiyi: {sum_XiYi:.3f}')
    a = np.array([[sum_Xi_2, sum_Xi],
                [sum_Xi, len(X)]])
    b = np.array([sum_XiYi ,sum_Yi])
    solve_4 = np.linalg.solve(a, b)

    print(f'Solución del sistema: {solve_4}')
    print(f'Regresión lineal (transformada log-log): Y = {solve_4[0]:.3f}X + {solve_4[1]:.3f}')
    f_trans_lin_2 = lambda x: solve_4[0]*x + solve_4[1]
    
    print("Grafica con la regresión lineal y la ptencia")
    Xi = np.linspace(np.min(X),np.max(X),1001)
    plt.plot(X, Y,'go')
    plt.plot(Xi, f_trans_lin_2(Xi),'-')
    plt.show()
    
    # función calculando la potencia
    f_pot = lambda x: np.exp(solve_4[1]) * x**(solve_4[0])
    a_0, a_1  = np.exp(solve_4[1]), solve_4[0]
    print(f'Regresión exponencial: Y = {a_0:.3f}*x^({a_1:.3f})')
    
    print("Grafica de la regresión de potencia")
    xi = np.linspace(np.min(x),np.max(x),1001)
    plt.plot(x, y,'o', label = 'Polinomio')
    plt.plot(xi, f_pot(xi),'b-', label = 'R.Exponencial')
    plt.legend()
    plt.xlabel('xi')
    plt.ylabel('fi')
    plt.title('Regresiones')
    plt.show()

# %% [markdown]
# ### Ejemplo práctico 1
#
# Si representamos los datos como puntos de coordenadas $(x_i,y_i)$ en el plano vemos que, efectivamente, éstos podrían ajustarse a una recta, lo que nos indica que la velocidad de reacción aumenta "linealmente" con la concentración de glucogenasa.
#
# |$x_i$|$y_i$|
# |--|--|
# |0.2|8|
# |0.5|10|
# |1|18|
# |2|35|
# |3|60|
#
#
# *Ejercicio tomado de URL:  [Ejercicios resueltos modulo de regresión](chrome-extension://efaidnbmnnnibpcajpcglclefindmkaj/https://www.um.es/docencia/jpastor/miweb_files/ficheros/ambientales/ambientales_2005_2006/regresion_resueltos.pdf)*

# %%
f = lambda x: 0.1*x + 1.25 + 0.2*np.random.randn(x.shape[0])

np.random.seed(42) # para poder reproducirlo
#f = lambda x: 0.1*x + 1.25 + 0.2*np.random.randn(x.shape[0])
x = np.arange(0, 20, 0.5) # generamos valores x de 0 a 20 en intervalos de 0.5
y = f(x) # calculamos y a partir de la función que hemos generado

x = np.array([0.2, 0.5, 1, 2, 3])
y = np.array([8, 10, 18, 35, 60])
grafica(x, y)

# %% [markdown]
# #### Regresión lineal

# %%
linear_regression(x, y)
# Out:
# ********** Regresión lineal ***********
# sum_xi: 6.700, sum_xi_2: 14.290
# sum_yi: 131.000, sum_xiyi: 274.600
# Solución del sistema: [18.64834337  1.21121988]
# Regresión lineal: y = 18.648x + 1.211

# %% [markdown]
# #### Regresión exponencial

# %%
exponential_regression(x, y)
# Out:
# ********** Regresión exponencial   ***********
# Y  [2.07944154 2.30258509 2.89037176 3.55534806 4.09434456]
# sum_xi: 6.700, sum_xi_2: 14.290
# sum_yi: 14.922, sum_xiyi: 23.851
# Regresión exponencial: Y = 7.477*e^(0.726*x)
# ************
# Grafica con la regresión lineal
# Regresión exponencial: Y = 7.477*e^(0.726*x)
# ********Fin Regresión exponencial

# %% [markdown]
# #### Regresión lineal (transformada semi-log)

# %%
regli_trans_semi_log(x, y)
# Out:
# ********** Regresión lineal (transformada semi-log) ***********
# Y  [2.07944154 2.30258509 2.89037176 3.55534806 4.09434456]
# sum_xi: 6.700, sum_xi_2: 14.290
# sum_yi: 14.922, sum_xiyi: 23.851
# Solución del sistema: [0.72584346 2.01178797]
# Regresión lineal (transformada semi-log): Y = 0.726x + 2.012

# %% [markdown]
# #### Regresión cuadrática

# %%
quadratic_regression(x, y)
# Out:
# ********** Regresión cuadrática ***********
# 6.7 14.29 36.132999999999996 98.0641
# 131 274.6 700.8199999999999
# Regresión cuadrática: y = 3.321x^2 + 8.029x + 5.949

# %% [markdown]
# #### Regresión de patencia

# %%
patenc_regression(x, y)
# Out:
# ********** Regresión de potancia ***********
# log y [2.07944154 2.30258509 2.89037176 3.55534806 4.09434456]
# log x [-1.60943791 -0.69314718  0.          0.69314718  1.09861229]
# grafica con la tranfomación de patencia
# Regresión lineal (transformada semi-log)
# sum_xi: -0.511, sum_xi_2: 4.758
# sum_yi: 14.922, sum_xiyi: 2.020
# Solución del sistema: [0.7531373  3.06136257]
# Regresión lineal (transformada log-log): Y = 0.753X + 3.061
# Grafica con la regresión lineal y la ptencia
# Regresión exponencial: Y = 21.357*x^(0.753)
# Grafica de la regresión de potencia
